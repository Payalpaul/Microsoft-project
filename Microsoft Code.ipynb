# %%
import pandas as pd

Microsoft_df=pd.read_csv('Microsoft_Data.csv')
Microsoft_df
# Out:
#                       MachineIdentifier   ProductName EngineVersion  \
# 0      0000028988387b115f69f31a3bf04f09  win8defender   1.1.15100.1
# 1      000007535c3f730efa9ea0b7ef1bd645  win8defender   1.1.14600.4
# 2      000007905a28d863f6d0d597892cd692  win8defender   1.1.15100.1
# 3      00000b11598a75ea8ba1beea8459149f  win8defender   1.1.15100.1
# 4      000014a5f00daa18e76b81417eeb99fc  win8defender   1.1.15100.1
# ...                                 ...           ...           ...
# 56751  01a3aaeba82aa3de04506d45fe2f8293  win8defender   1.1.15100.1
# 56752  01a3aef1a1af51ef3e4aa0a1c99bf8b6  win8defender   1.1.15100.1
# 56753  01a3af52c05b6af7d971d5f3092c3a80  win8defender   1.1.15200.1
# 56754  01a3b0c12114367eb99eaa2fac6b754c  win8defender   1.1.15100.1
# 56755  01a3b14d2c2d4f1bc85204d10713884d  win8defender   1.1.15200.1
#
#             AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  \
# 0      4.18.1807.18075  1.273.1735.0       0               7.0
# ...

# %%
import pandas as pd

Microsoft_df=pd.read_csv('Microsoft_Data.csv')
Microsoft_df.shape
# Out:
# (56756, 83)

# %%
import pandas as pd

Microsoft_df=pd.read_csv('Microsoft_Data.csv')
Microsoft_df.columns
# Out:
# Index(['MachineIdentifier', 'ProductName', 'EngineVersion', 'AppVersion',
#        'AvSigVersion', 'IsBeta', 'RtpStateBitfield', 'IsSxsPassiveMode',
#        'DefaultBrowsersIdentifier', 'AVProductStatesIdentifier',
#        'AVProductsInstalled', 'AVProductsEnabled', 'HasTpm',
#        'CountryIdentifier', 'CityIdentifier', 'OrganizationIdentifier',
#        'GeoNameIdentifier', 'LocaleEnglishNameIdentifier', 'Platform',
#        'Processor', 'OsVer', 'OsBuild', 'OsSuite', 'OsPlatformSubRelease',
#        'OsBuildLab', 'SkuEdition', 'IsProtected', 'AutoSampleOptIn', 'PuaMode',
#        'SMode', 'IeVerIdentifier', 'SmartScreen', 'Firewall', 'UacLuaenable',
#        'Census_MDC2FormFactor', 'Census_DeviceFamily',
#        'Census_OEMNameIdentifier', 'Census_OEMModelIdentifier',
#        'Census_ProcessorCoreCount', 'Census_ProcessorManufacturerIdentifier',
#        'Census_ProcessorModelIdentifier', 'Census_ProcessorClass',
# ...

# %%
import pandas as pd

Microsoft_df=pd.read_csv('Microsoft_Data.csv')
Microsoft_df.shape[1]
# Out:
# 83

# %%
import pandas as pd

Microsoft_df=pd. read_csv('Microsoft_Data.csv')
Microsoft_df.shape
Microsoft_df.columns
Microsoft_df['HasDetections']
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 56751    0
# 56752    1
# 56753    0
# 56754    1
# 56755    1
# Name: HasDetections, Length: 56756, dtype: int64

# %%
import pandas as pd

Microsoft_df=pd.read_csv('Microsoft_Data.csv')
Microsoft_df.shape
Microsoft_df.columns
Microsoft_df[['HasDetections','OsBuild']]
# Out:
#        HasDetections  OsBuild
# 0                  0    17134
# 1                  0    17134
# 2                  0    17134
# 3                  1    17134
# 4                  1    17134
# ...              ...      ...
# 56751              0    16299
# 56752              1    17134
# 56753              0    17134
# 56754              1    17134
# 56755              1    17134
#
# [56756 rows x 2 columns]

# %%
import pandas as pd

Microsoft_df=pd. read_csv('Microsoft_Data.csv')
Microsoft_df.shape
Microsoft_df.columns
Microsoft_df['HasDetections'].value_counts() # Value_counts is only for categotrical varibles.
Microsoft_df['OsBuild']
Microsoft_df['OsBuild']=Microsoft_df['OsBuild'].astype('object') # to change integer as object.as type will 
Microsoft_df['OsBuild'].dtype
Microsoft_df['OsBuild'].value_counts()  # here we can use. values to see it is series
# Out:
# 17134    24896
# 16299    15873
# 15063     5076
# 14393     4636
# 10586     2614
# 10240     1713
# 9600      1191
# 7601       624
# 17692       15
# 17738       15
# 17744       13
# 17758       11
# 17713       10
# 17741        9
# 17754        8
# 17746        8
# 17735        6
# 17755        5
# 17751        5
# 17763        4
# 7600         4
# 17760        3
# 17666        3
# 17677        2
# 17740        1
# 17733        1
# 17730        1
# 17759        1
# 17704        1
# 17747        1
# 17686        1
# 17682        1
# 17672        1
# 17661        1
# 17643        1
# 17761        1
# Name: OsBuild, dtype: int64

# %%
import pandas as pd # to find out the missing values in a column name, missing value and percentage

Microsoft_df=pd.read_csv('Microsoft_Data.csv')
Microsoft_df.columns
Microsoft_df['OsBuild']
Microsoft_df.isnull().sum()

missing_values_df=pd.DataFrame({'Column_Name':Microsoft_df.columns,
                               'Missing_values_count':Microsoft_df.isnull().sum(),
                               'Missing_values_percentage':Microsoft_df.isnull().sum()/Microsoft_df.shape[0]*100})

missing_values_df.sort_values(by='Missing_values_percentage',ascending=False)

# print(missing_values_df['Missing_values_percentage'])

# Droping columns with missing value percentage greater then 50

cols_to_drop=list(missing_values_df[missing_values_df['Missing_values_percentage']>50]['Column_Name'])

Microsoft_df.drop(columns=cols_to_drop,inplace=True)

Microsoft_df.columns
# Out:
# Index(['MachineIdentifier', 'ProductName', 'EngineVersion', 'AppVersion',
#        'AvSigVersion', 'IsBeta', 'RtpStateBitfield', 'IsSxsPassiveMode',
#        'AVProductStatesIdentifier', 'AVProductsInstalled', 'AVProductsEnabled',
#        'HasTpm', 'CountryIdentifier', 'CityIdentifier',
#        'OrganizationIdentifier', 'GeoNameIdentifier',
#        'LocaleEnglishNameIdentifier', 'Platform', 'Processor', 'OsVer',
#        'OsBuild', 'OsSuite', 'OsPlatformSubRelease', 'OsBuildLab',
#        'SkuEdition', 'IsProtected', 'AutoSampleOptIn', 'SMode',
#        'IeVerIdentifier', 'SmartScreen', 'Firewall', 'UacLuaenable',
#        'Census_MDC2FormFactor', 'Census_DeviceFamily',
#        'Census_OEMNameIdentifier', 'Census_OEMModelIdentifier',
#        'Census_ProcessorCoreCount', 'Census_ProcessorManufacturerIdentifier',
#        'Census_ProcessorModelIdentifier', 'Census_PrimaryDiskTotalCapacity',
#        'Census_PrimaryDiskTypeName', 'Census_SystemVolumeTotalCapacity',
# ...

# %%
#  Chi-Square test used to test for the correlation b/w two categorical variables
import scipy.stats

crosstab=pd.crosstab(Microsoft_df['OsBuild'],Microsoft_df['HasDetections']) #Builds the contingency table

result=scipy.stats.chi2_contingency(crosstab) # Outputs the chi-squares test statistic, p-value and degrees of
result
# Out:
# (158.07149922833526,
#  1.434114178500418e-17,
#  35,
#  array([[1.99478469e+00, 2.00521531e+00],
#         [3.11186412e+02, 3.12813588e+02],
#         [5.93947142e+02, 5.97052858e+02],
#         [8.54266545e+02, 8.58733455e+02],
#         [1.30359180e+03, 1.31040820e+03],
#         [2.31195546e+03, 2.32404454e+03],
#         [2.53138177e+03, 2.54461823e+03],
#         [7.91580436e+03, 7.95719564e+03],
#         [1.24155399e+04, 1.24804601e+04],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e-01, 5.01303827e-01],
#         [1.49608852e+00, 1.50391148e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [9.97392346e-01, 1.00260765e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e-01, 5.01303827e-01],
#         [7.48044260e+00, 7.51955740e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e+00, 5.01303827e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e-01, 5.01303827e-01],
# ...

# %%
import scipy.stats

crosstab=pd.crosstab(Microsoft_df['OsBuild'],Microsoft_df['HasDetections']) #Builds the contingency table

result=scipy.stats.chi2_contingency(crosstab) # Outputs the chi-squares test statistic, p-value and degrees of
crosstab
# Out:
# HasDetections      0      1
# OsBuild
# 7600               3      1
# 7601             314    310
# 9600             588    603
# 10240            872    841
# 10586           1383   1231
# 14393           2520   2116
# 15063           2638   2438
# 16299           8090   7783
# 17134          11820  13076
# 17643              0      1
# 17661              1      0
# 17666              3      0
# 17672              1      0
# 17677              1      1
# 17682              1      0
# 17686              1      0
# 17692              7      8
# 17704              1      0
# 17713              9      1
# 17730              0      1
# 17733              1      0
# 17735              4      2
# 17738              8      7
# 17740              1      0
# 17741              4      5
# 17744             10      3
# 17746              3      5
# 17747              1      0
# 17751              4      1
# 17754              4      4
# 17755              4      1
# 17758              3      8
# ...

# %%
import scipy.stats

crosstab=pd.crosstab(Microsoft_df['OsBuild'],Microsoft_df['HasDetections']) #Builds the contingency table

result=scipy.stats.chi2_contingency(crosstab) # Outputs the chi-squares test statistic, p-value and degrees of
result

print('p-value is:',result[0])
# Out:
# p-value is: 158.07149922833526

# %%
import scipy.stats

crosstab=pd.crosstab(Microsoft_df['OsBuild'],Microsoft_df['HasDetections']) #Builds the contingency table

result=scipy.stats.chi2_contingency(crosstab) # Outputs the chi-squares test statistic, p-value and degrees of
result
# Out:
# (158.07149922833526,
#  1.434114178500418e-17,
#  35,
#  array([[1.99478469e+00, 2.00521531e+00],
#         [3.11186412e+02, 3.12813588e+02],
#         [5.93947142e+02, 5.97052858e+02],
#         [8.54266545e+02, 8.58733455e+02],
#         [1.30359180e+03, 1.31040820e+03],
#         [2.31195546e+03, 2.32404454e+03],
#         [2.53138177e+03, 2.54461823e+03],
#         [7.91580436e+03, 7.95719564e+03],
#         [1.24155399e+04, 1.24804601e+04],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e-01, 5.01303827e-01],
#         [1.49608852e+00, 1.50391148e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [9.97392346e-01, 1.00260765e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e-01, 5.01303827e-01],
#         [7.48044260e+00, 7.51955740e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e+00, 5.01303827e+00],
#         [4.98696173e-01, 5.01303827e-01],
#         [4.98696173e-01, 5.01303827e-01],
# ...

# %%
cols_to_drop=[]
for col in Microsoft_df.columns:
    if Microsoft_df[col].nunique()==Microsoft_df.shape[0] or Microsoft_df[col].nunique()==1:
        cols_to_drop.append(col)
cols_to_drop
# Out:
# ['MachineIdentifier', 'IsBeta', 'AutoSampleOptIn', 'Census_IsFlightsDisabled']

# %%
cols_to_drop=[]
for col in Microsoft_df.columns:
    if Microsoft_df[col].nunique()==Microsoft_df.shape[0] or Microsoft_df[col].nunique()==1:
        cols_to_drop.append(col)
Microsoft_df.drop(columns=cols_to_drop,inplace=True)
Microsoft_df.columns
# Out:
# Index(['ProductName', 'EngineVersion', 'AppVersion', 'AvSigVersion',
#        'RtpStateBitfield', 'IsSxsPassiveMode', 'DefaultBrowsersIdentifier',
#        'AVProductStatesIdentifier', 'AVProductsInstalled', 'AVProductsEnabled',
#        'HasTpm', 'CountryIdentifier', 'CityIdentifier',
#        'OrganizationIdentifier', 'GeoNameIdentifier',
#        'LocaleEnglishNameIdentifier', 'Platform', 'Processor', 'OsVer',
#        'OsBuild', 'OsSuite', 'OsPlatformSubRelease', 'OsBuildLab',
#        'SkuEdition', 'IsProtected', 'SMode', 'IeVerIdentifier', 'SmartScreen',
#        'Firewall', 'UacLuaenable', 'Census_MDC2FormFactor',
#        'Census_DeviceFamily', 'Census_OEMNameIdentifier',
#        'Census_OEMModelIdentifier', 'Census_ProcessorCoreCount',
#        'Census_ProcessorManufacturerIdentifier',
#        'Census_ProcessorModelIdentifier', 'Census_ProcessorClass',
#        'Census_PrimaryDiskTotalCapacity', 'Census_PrimaryDiskTypeName',
# ...

# %%
cols_to_drop=[]
for col in Microsoft_df.columns:
    if Microsoft_df[col].nunique()==Microsoft_df.shape[0] or Microsoft_df[col].nunique()==1:
        cols_to_drop.append(col)
Microsoft_df.drop(columns=cols_to_drop,inplace=True)
Microsoft_df.columns

Microsoft_df['Census_PrimaryDiskTotalCapacity'].nunique()
# Out:
# 345

# %%
import pandas as pd 

Microsoft_df=pd.read_csv('Microsoft_Data.csv')
Microsoft_df.shape
Microsoft_df.isnull().sum()

Microsoft_df=pd.read_csv('Microsoft_Data.csv')

y=Microsoft_df['HasDetections']

Microsoft_df.drop(columns='HasDetections',inplace=True)

missing_values_df=pd.DataFrame({'Column_Name':Microsoft_df.columns,
                               'Missing_values_count':Microsoft_df.isnull().sum(),
                               'Missing_values_percentage':Microsoft_df.isnull().sum()/Microsoft_df.shape[0]*100})

missing_values_df.sort_values(by='Missing_values_percentage',ascending=False)
missing_values_df
# Out:
#                                                                      Column_Name  \
# MachineIdentifier                                              MachineIdentifier
# ProductName                                                          ProductName
# EngineVersion                                                      EngineVersion
# AppVersion                                                            AppVersion
# AvSigVersion                                                        AvSigVersion
# ...                                                                          ...
# Census_IsTouchEnabled                                      Census_IsTouchEnabled
# Census_IsPenCapable                                          Census_IsPenCapable
# Census_IsAlwaysOnAlwaysConnectedCapable  Census_IsAlwaysOnAlwaysConnectedCapable
# Wdft_IsGamer                                                        Wdft_IsGamer
# Wdft_RegionIdentifier                                      Wdft_RegionIdentifier
# ...

# %%
# Columns  to drop whose missing values are unique and has one unique value for all records  
cols_to_drop=[]

cols_with_missing_values_grt_50=list(missing_values_df[missing_values_df['Missing_values_percentage']>50]['Column_Name'])

for col in Microsoft_df.columns:
    if Microsoft_df[col].nunique()==Microsoft_df.shape[0] or Microsoft_df[col].nunique()==1:
        cols_to_drop.append(col)
        
columns_to_drop=cols_to_drop+cols_with_missing_values_grt_50
Microsoft_df.drop(columns=cols_to_drop,inplace=True)

Microsoft_df.shape
# Out:
# (56756, 75)

# %%
for col in Microsoft_df.columns:
    if col!='Census_SystemVolumeTotalCapacity':
        Microsoft_df[col]=Microsoft_df[col].astype('object')
        
Microsoft_df['Census_SystemVolumeTotalCapacity'].dtype
# Out:
# dtype('float64')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(Microsoft_df,y,test_size=0.3,random_state=43)

# Filling missing values
for col in X_train.columns:
    if X_train[col].dtype=='object':
        X_train[col]=X_train[col].fillna(X_train[col].mode()[0]).astype(object)
        X_test[col]=X_test[col].fillna(X_train[col].mode()[0]).astype(object)
        
    else:
        X_train[col]=X_train[col].fillna(X_train[col].mean())
        X_test[col]=X_test[col].fillna(X_train[col].mean())
X_train
X_test
# Out:
# C:\Users\pihub\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\pihub\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\pihub\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np


class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoderExt()

for col in X_train.columns:
    if X_train[col].dtype=='object':
        le.fit(X_train[col])
        X_train[col]=le.transform(X_train[col])
        X_test[col]=le.transform(X_test[col])
        
X_train
# Out:
# C:\Users\pihub\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\pihub\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#        MachineIdentifier  ProductName  EngineVersion  AppVersion  \
# 55739              39026            2             33          63
# 29687              20744            2             32          36
# ...

# %%
from sklearn.linear_model import LogisticRegression

logreg=LogisticRegression()

logreg.fit(X_train,y_train)



y_pred=logreg.predict(X_test)

y_pred
# Out:
# C:\Users\pihub\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
comparisons_df=pd.DataFrame({'Actuals':y_test,'Predictions':y_pred})

from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score,roc_curve,roc_auc_score

confusion_matrix(y_test,y_pred)

recall_score(y_test,y_pred)
precision_score(y_test,y_pred)

f1_score(y_test,y_pred)
# Out:
# 0.5045667736361392

# %%
# AUC-ROC Curve for logistics regression

y_pred_proba = logreg.predict_proba(X_test)[::,1]

y_pred_proba

fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba) # the function roc_curve returns three values, the False Positive Rate,True Positive rate
                                                # threshold values it used to calculate the TPR and FPR

auc = roc_auc_score(y_test, y_pred_proba)

plt.plot(fpr,tpr,label="auc="+str(auc))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')

plt.legend(loc=5)
plt.show()

# %%
scores_df=pd.DataFrame({'FPR':fpr,'Thresholds':thresholds})
scores_df

# %%
# navie_bayes classifier 

from sklearn.naive_bayes import MultinomialNB

MultinomialNB =MultinomialNB()

MultinomialNB.fit(X_train,y_train)

y_pred=MultinomialNB.predict(X_test)

y_pred

# %%
# AUC-ROC Curve for naive_bayes
y_pred_proba = MultinomialNB.predict(X_test_proba)[::,1]

y_pred_proba

fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba) # the function roc_curve return three values, the false 
                                                  # thresholds values it used to calculate the TPR and FPR
auc = roc_auc_score(y_test,y_pred_proba)

plt.plot(fpr,tpr,label="auc="+str(auc))   
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')    
plt.title('AUC-ROC Curve')

plt.legend(loc=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-19a7998137e7> in <module>
#       1 # AUC-ROC Curve for naive_bayes
# ----> 2 y_pred_proba = MultinomialNB.predict(X_test_proba)[::,1]
#       3
#       4 y_pred_proba
#       5
#
# NameError: name 'X_test_proba' is not defined

# %%
y_pred_proba = logreg.predict_proba(X_test)[::,1]

y_pred_proba

fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba) # the function roc_curve returns three values, the False Positive Rate,True Positive rate
                                                # threshold values it used to calculate the TPR and FPR

auc = roc_auc_score(y_test, y_pred_proba)

plt.plot(fpr,tpr,label="auc="+str(auc))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')

plt.legend(loc=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-2b45428b252f> in <module>
# ----> 1 y_pred_proba = logreg.predict_proba(X_test)[::,1]
#       2
#       3 y_pred_proba
#       4
#       5 fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba) # the function roc_curve returns three values, the False Positive Rate,True Positive rate
#
# NameError: name 'logreg' is not defined
